# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x, y = np.loadtxt('Neuron1_Potentials.txt', delimiter = ':::', unpack = True)

# %%
plt.plot(x,y, 'r')
plt.grid()
plt.title('Neuron 1 Membrane Potential')
plt.xlabel('Time in ms')
plt.ylabel('Potential in mV')
plt.show()

# %%
a, b = np.loadtxt('Neuron2_Potentials.txt', delimiter = ':::', unpack = True)

# %%
plt.plot(a,b, 'b')
plt.grid()
plt.title('Neuron 2 Membrane Potential')
plt.xlabel('Time in ms')
plt.ylabel('Potential in mV')
plt.show()
